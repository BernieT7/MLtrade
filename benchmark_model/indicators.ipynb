# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("testing_data.csv")
df = data.copy()
df= df.iloc[::5, :]

# %%
df
# Out:
#             timestamp                                                bid  \
# 0     2025/9/15 14:37  [116217.08, 116217.07, 116216.94, 116216.9, 11...
# 5     2025/9/15 14:42  [116201.8, 116201.79, 116201.78, 116201.77, 11...
# 10    2025/9/15 14:47  [116215.97, 116215.96, 116215.95, 116215.86, 1...
# 15    2025/9/15 14:52  [116124.44, 116124.43, 116124.42, 116124.26, 1...
# 20    2025/9/15 14:57  [116126.11, 116126.1, 116126.09, 116126.08, 11...
# ...               ...                                                ...
# 9790  2025/9/22 09:50  [114604.46, 114604.45, 114604.44, 114604.12, 1...
# 9795  2025/9/22 09:55  [114304.92, 114304.91, 114304.9, 114304.58, 11...
# 9800  2025/9/22 10:00  [114441.23, 114441.22, 114441.13, 114441.12, 1...
# 9805  2025/9/22 10:05  [114431.97, 114431.96, 114430.64, 114429.22, 1...
# 9810  2025/9/22 10:10  [114516.2, 114516.19, 114515.89, 114515.88, 11...
#
#                                                 bid_qty  \
# 0     [1.17942, 0.00075, 8e-05, 0.00032, 5e-05, 0.00...
# 5     [7.58827, 0.0003, 0.0002, 0.0001, 0.0001, 0.81...
# 10    [2.2097, 0.00075, 0.0001, 0.0001, 0.22746, 0.0...
# 15    [0.20812, 0.00055, 0.0001, 0.0001, 0.26411, 0....
# 20    [10.43524, 0.06304, 0.0001, 0.0001, 5e-05, 0.0...
# ...                                                 ...
# 9790  [4.11511, 0.0008, 0.0001, 0.00534, 0.0001, 0.0...
# 9795  [0.92895, 0.00091, 0.0001, 0.00015, 5e-05, 0.0...
# 9800  [10.90952, 0.0001, 0.06452, 0.0001, 0.04, 0.00...
# 9805  [3.8218, 0.0001, 5e-05, 0.0001, 5e-05, 5e-05, ...
# 9810  [1.05985, 0.0004, 0.0001, 0.08057, 5e-05, 0.00...
#
#                                                     ask  \
# 0     [116217.09, 116217.1, 116217.11, 116217.57, 11...
# 5     [116201.81, 116201.82, 116201.83, 116202.24, 1...
# 10    [116215.98, 116215.99, 116216.0, 116216.01, 11...
# 15    [116124.45, 116124.46, 116124.47, 116124.92, 1...
# 20    [116126.12, 116126.13, 116126.14, 116126.21, 1...
# ...                                                 ...
# 9790  [114604.47, 114604.48, 114604.52, 114604.53, 1...
# 9795  [114304.93, 114304.94, 114306.07, 114306.08, 1...
# 9800  [114441.24, 114441.25, 114441.26, 114442.18, 1...
# 9805  [114431.98, 114431.99, 114432.0, 114432.02, 11...
# 9810  [114516.21, 114516.22, 114516.23, 114516.26, 1...
#
#                                                 ask_qty       open       high  \
# 0     [16.97198, 3.0666, 0.0001, 0.0001, 0.0001, 0.4...  116232.07  116253.49
# 5     [0.97061, 0.0003, 0.0001, 5e-05, 5e-05, 0.0001...  116160.01  116201.80
# 10    [10.06898, 0.08993, 0.00125, 5e-05, 0.0001, 0....  116215.98  116215.99
# 15    [14.43589, 0.10872, 5e-05, 0.0001, 0.0001, 0.0...  116120.09  116130.00
# 20    [4.42556, 0.0011, 0.0001, 0.0001, 0.07281, 0.0...  116103.30  116126.52
# ...                                                 ...        ...        ...
# 9790  [7.34373, 0.00015, 5e-05, 0.92751, 0.0001, 5e-...  114607.72  114607.73
# 9795  [10.24242, 0.00174, 5e-05, 0.04025, 5e-05, 5e-...  114333.55  114334.85
# 9800  [1.00038, 0.00035, 0.0001, 5e-05, 5e-05, 0.000...  114273.44  114472.47
# 9805  [6.11936, 0.61935, 0.0001, 0.0001, 0.06468, 0....  114472.78  114566.31
# 9810  [7.24764, 0.01056, 0.0001, 0.0001, 0.0907, 0.0...  114520.43  114520.43
#
#             low      close    volume  open interest
# 0     116217.08  116217.08   2.90457      88930.773
# 5     116160.00  116201.80   1.17942      88961.407
# 10    116209.65  116215.98   6.35120      89011.435
# 15    116120.08  116124.45   0.62716      88939.875
# 20    116103.30  116126.11   0.99582      88994.996
# ...         ...        ...       ...            ...
# 9790  114604.46  114604.47   5.50556      88730.815
# 9795  114304.92  114304.92   8.11695      88857.927
# 9800  114273.44  114441.24  46.06661      88897.333
# 9805  114429.12  114431.98  13.38720      88748.093
# 9810  114516.20  114516.21   6.19556      88748.667
#
# [1963 rows x 11 columns]

# %%
df["spread"] = [float(ask[1: -1].split(", ")[0]) - float(bid[1: -1].split(", ")[0]) for bid, ask in zip(df["bid"], df["ask"])]
df["mid price"] = [(float(ask[1: -1].split(", ")[0]) + float(bid[1: -1].split(", ")[0]))/2 for bid, ask in zip(df["bid"], df["ask"])]

# %%
df[["log spread", "log price", "log volume"]] = np.log(df[["spread", "close", "volume"]])

# %%
df
# Out:
#             timestamp                                                bid  \
# 0     2025/9/15 14:37  [116217.08, 116217.07, 116216.94, 116216.9, 11...
# 5     2025/9/15 14:42  [116201.8, 116201.79, 116201.78, 116201.77, 11...
# 10    2025/9/15 14:47  [116215.97, 116215.96, 116215.95, 116215.86, 1...
# 15    2025/9/15 14:52  [116124.44, 116124.43, 116124.42, 116124.26, 1...
# 20    2025/9/15 14:57  [116126.11, 116126.1, 116126.09, 116126.08, 11...
# ...               ...                                                ...
# 9790  2025/9/22 09:50  [114604.46, 114604.45, 114604.44, 114604.12, 1...
# 9795  2025/9/22 09:55  [114304.92, 114304.91, 114304.9, 114304.58, 11...
# 9800  2025/9/22 10:00  [114441.23, 114441.22, 114441.13, 114441.12, 1...
# 9805  2025/9/22 10:05  [114431.97, 114431.96, 114430.64, 114429.22, 1...
# 9810  2025/9/22 10:10  [114516.2, 114516.19, 114515.89, 114515.88, 11...
#
#                                                 bid_qty  \
# 0     [1.17942, 0.00075, 8e-05, 0.00032, 5e-05, 0.00...
# 5     [7.58827, 0.0003, 0.0002, 0.0001, 0.0001, 0.81...
# 10    [2.2097, 0.00075, 0.0001, 0.0001, 0.22746, 0.0...
# 15    [0.20812, 0.00055, 0.0001, 0.0001, 0.26411, 0....
# 20    [10.43524, 0.06304, 0.0001, 0.0001, 5e-05, 0.0...
# ...                                                 ...
# 9790  [4.11511, 0.0008, 0.0001, 0.00534, 0.0001, 0.0...
# 9795  [0.92895, 0.00091, 0.0001, 0.00015, 5e-05, 0.0...
# 9800  [10.90952, 0.0001, 0.06452, 0.0001, 0.04, 0.00...
# 9805  [3.8218, 0.0001, 5e-05, 0.0001, 5e-05, 5e-05, ...
# 9810  [1.05985, 0.0004, 0.0001, 0.08057, 5e-05, 0.00...
#
#                                                     ask  \
# 0     [116217.09, 116217.1, 116217.11, 116217.57, 11...
# 5     [116201.81, 116201.82, 116201.83, 116202.24, 1...
# 10    [116215.98, 116215.99, 116216.0, 116216.01, 11...
# 15    [116124.45, 116124.46, 116124.47, 116124.92, 1...
# 20    [116126.12, 116126.13, 116126.14, 116126.21, 1...
# ...                                                 ...
# 9790  [114604.47, 114604.48, 114604.52, 114604.53, 1...
# 9795  [114304.93, 114304.94, 114306.07, 114306.08, 1...
# 9800  [114441.24, 114441.25, 114441.26, 114442.18, 1...
# 9805  [114431.98, 114431.99, 114432.0, 114432.02, 11...
# 9810  [114516.21, 114516.22, 114516.23, 114516.26, 1...
#
#                                                 ask_qty       open       high  \
# 0     [16.97198, 3.0666, 0.0001, 0.0001, 0.0001, 0.4...  116232.07  116253.49
# 5     [0.97061, 0.0003, 0.0001, 5e-05, 5e-05, 0.0001...  116160.01  116201.80
# 10    [10.06898, 0.08993, 0.00125, 5e-05, 0.0001, 0....  116215.98  116215.99
# 15    [14.43589, 0.10872, 5e-05, 0.0001, 0.0001, 0.0...  116120.09  116130.00
# 20    [4.42556, 0.0011, 0.0001, 0.0001, 0.07281, 0.0...  116103.30  116126.52
# ...                                                 ...        ...        ...
# 9790  [7.34373, 0.00015, 5e-05, 0.92751, 0.0001, 5e-...  114607.72  114607.73
# 9795  [10.24242, 0.00174, 5e-05, 0.04025, 5e-05, 5e-...  114333.55  114334.85
# 9800  [1.00038, 0.00035, 0.0001, 5e-05, 5e-05, 0.000...  114273.44  114472.47
# 9805  [6.11936, 0.61935, 0.0001, 0.0001, 0.06468, 0....  114472.78  114566.31
# 9810  [7.24764, 0.01056, 0.0001, 0.0001, 0.0907, 0.0...  114520.43  114520.43
#
#             low      close    volume  open interest  spread   mid price  \
# 0     116217.08  116217.08   2.90457      88930.773    0.01  116217.085
# 5     116160.00  116201.80   1.17942      88961.407    0.01  116201.805
# 10    116209.65  116215.98   6.35120      89011.435    0.01  116215.975
# 15    116120.08  116124.45   0.62716      88939.875    0.01  116124.445
# 20    116103.30  116126.11   0.99582      88994.996    0.01  116126.115
# ...         ...        ...       ...            ...     ...         ...
# 9790  114604.46  114604.47   5.50556      88730.815    0.01  114604.465
# 9795  114304.92  114304.92   8.11695      88857.927    0.01  114304.925
# 9800  114273.44  114441.24  46.06661      88897.333    0.01  114441.235
# 9805  114429.12  114431.98  13.38720      88748.093    0.01  114431.975
# 9810  114516.20  114516.21   6.19556      88748.667    0.01  114516.205
#
#       log spread  log price  log volume
# 0       -4.60517  11.663215    1.066285
# 5       -4.60517  11.663084    0.165023
# 10      -4.60517  11.663206    1.848644
# 15      -4.60517  11.662418   -0.466554
# 20      -4.60517  11.662432   -0.004189
# ...          ...        ...         ...
# 9790    -4.60517  11.649242    1.705758
# 9795    -4.60517  11.646625    2.093954
# 9800    -4.60517  11.647817    3.830088
# 9805    -4.60517  11.647736    2.594299
# 9810    -4.60517  11.648472    1.823833
#
# [1963 rows x 16 columns]

# %%
total_bid_qty = []
for qty in df["bid_qty"]:
  qty_list = qty[1: -1].split(", ")
  temp_qty = 0
  for i in range(len(qty_list)):
    temp_qty += float(qty_list[i])
  total_bid_qty.append(temp_qty)

total_ask_qty = []
for qty in df["ask_qty"]:
  qty_list = qty[1: -1].split(", ")
  temp_qty = 0
  for i in range(len(qty_list)):
    temp_qty += float(qty_list[i])
  total_ask_qty.append(temp_qty)

df["bid total qty"] = total_bid_qty
df["ask total qty"] = total_ask_qty

# %%
df["order imbalance"] = (df["bid total qty"] - df["ask total qty"])/(df["bid total qty"] + df["ask total qty"])

# %%
df["delta price_t"] = df["log price"] - df["log price"].shift(1)
df["delta price_t-1"] = df["log price"].shift(1) - df["log price"].shift(2)
df["delta price_t-2"] = df["log price"].shift(2) - df["log price"].shift(3)
df["delta price_t-3"] = df["log price"].shift(3) - df["log price"].shift(4)
df["delta price_t-4"] = df["log price"].shift(4) - df["log price"].shift(5)
df["delta price_t-5"] = df["log price"].shift(5) - df["log price"].shift(6)
df["delta price_t-6"] = df["log price"].shift(6) - df["log price"].shift(7)
df["delta price_t-7"] = df["log price"].shift(7) - df["log price"].shift(8)
# df["delta volume"] = df["log volume"] - df["log volume"].shift(1)

# %%
df["ret"] = df["close"].pct_change()
# df['direction'] = np.where(df['ret']>=0,1,-1)
# df['direction'][0] = 0
# df['vol_adj'] = df['volume'] * df['direction']
# df['obv'] = df['vol_adj'].cumsum()

# %%
vol = []
for i in range(len(df["ret"])):
 if i<10:
  temp = df["ret"][:i].std()
 else:
  temp = df["ret"][i-10:i].std()
 vol.append(temp)
df["vol"] = vol

# %%
window=14
df["gain"] = np.where(df["delta price_t"]>=0, df["delta price_t"], 0)
df["loss"] = np.where(df["delta price_t"]<0, -df["delta price_t"], 0)
df["avg gain"] = df["gain"].ewm(alpha=1/window, min_periods=window).mean()
df["avg loss"] = df["loss"].ewm(alpha=1/window, min_periods=window).mean()
df["RS"] = df["avg gain"]/df["avg loss"]
df["RSI"] = 100 - (100/(1+df["RS"]))

# %%
slow_window = 26
fast_window = 12
signal_window = 9
df["slow_ema"] = df["close"].ewm(span=slow_window, min_periods=slow_window).mean()
df["fast_ema"] = df["close"].ewm(span=fast_window, min_periods=fast_window).mean()
df["macd"] = df["fast_ema"] - df["slow_ema"]
df["signal"] = df["macd"].ewm(span=signal_window, min_periods=signal_window).mean()
df["macd signal"] = df["macd"] - df["signal"]

# %%
n = 20
df['H-L']=abs(df['high']-df['low'])
df['H-PC']=abs(df['high']-df['close'].shift(1))
df['L-PC']=abs(df['low']-df['close'].shift(1))
df['TR']=df[['H-L','H-PC','L-PC']].max(axis=1,skipna=False)
df['ATR'] = df['TR'].rolling(n).mean()
df['ATR'] = df['TR'].ewm(span=n,adjust=False,min_periods=n).mean()
df['ATR%'] = df['ATR']/df['close']

# %%
window = 14
df["+change"] = df["high"] - df["high"].shift(1)
df["-change"] = df["low"].shift(1) - df["low"]
df["+DM"] = np.where((df["+change"] > df["-change"]) & (df["+change"] > 0), df["+change"], 0)
df["-DM"] = np.where((df["-change"] > df["+change"]) & (df["-change"] > 0), df["-change"], 0)
df["+DI14"] = 100 * (df["+DM"].ewm(com=window, min_periods=window).mean() / df["ATR"])
df["-DI14"] = 100 * (df["-DM"].ewm(com=window, min_periods=window).mean() / df["ATR"])
df["DX"] = 100 * (abs(df["+DI14"] - df["-DI14"]) / (df["+DI14"] + df["-DI14"]))
df["ADX"] = df["DX"].ewm(com=window, min_periods=window).mean()

# %%
df["future 10t return"] = df['close'].shift(-10) / df['close'] - 1

# %%
df.dropna(inplace=True)

# %%
df[["log ADX"]] = np.log(df[["ADX"]])

# %%
df
# Out:
#             timestamp                                                bid  \
# 165   2025/9/15 17:22  [115031.79, 115031.78, 115031.77, 115031.75, 1...
# 170   2025/9/15 17:27  [115149.54, 115149.3, 115148.99, 115148.98, 11...
# 175   2025/9/15 17:32  [115086.65, 115086.64, 115086.63, 115086.62, 1...
# 180   2025/9/15 17:37  [114964.33, 114964.32, 114964.31, 114964.02, 1...
# 185   2025/9/15 17:42  [114940.02, 114940.01, 114940.0, 114939.99, 11...
# ...               ...                                                ...
# 9740  2025/9/22 09:00  [114300.01, 114300.0, 114299.99, 114298.89, 11...
# 9745  2025/9/22 09:05  [114523.28, 114523.27, 114523.24, 114523.23, 1...
# 9750  2025/9/22 09:10  [114427.99, 114427.98, 114427.94, 114427.93, 1...
# 9755  2025/9/22 09:15  [114600.0, 114599.99, 114599.98, 114599.9, 114...
# 9760  2025/9/22 09:20  [114512.89, 114512.88, 114512.87, 114512.86, 1...
#
#                                                 bid_qty  \
# 165   [6.77899, 0.0004, 0.0001, 0.0001, 0.28702, 0.0...
# 170   [15.0642, 0.0001, 5e-05, 0.14687, 0.47012, 0.3...
# 175   [2.27903, 0.00025, 0.0001, 0.0001, 0.54181, 0....
# 180   [0.57701, 0.00085, 0.0001, 5e-05, 0.00275, 0.0...
# 185   [3.8561, 0.00115, 0.02088, 0.0001, 0.0002, 0.3...
# ...                                                 ...
# 9740  [5.69316, 0.02571, 0.0001, 0.0001, 0.48194, 0....
# 9745  [7.61718, 0.0001, 0.83891, 0.04017, 0.0001, 5e...
# 9750  [12.13381, 0.0001, 5e-05, 0.0001, 0.00019, 0.0...
# 9755  [1.02626, 0.00105, 0.0001, 5e-05, 5e-05, 0.000...
# 9760  [0.34816, 0.0009, 5e-05, 0.0001, 5e-05, 5e-05,...
#
#                                                     ask  \
# 165   [115031.8, 115031.81, 115031.82, 115031.93, 11...
# 170   [115149.55, 115149.56, 115149.57, 115149.79, 1...
# 175   [115086.66, 115086.67, 115086.68, 115086.85, 1...
# 180   [114964.34, 114964.35, 114964.36, 114964.62, 1...
# 185   [114940.03, 114940.04, 114940.05, 114940.38, 1...
# ...                                                 ...
# 9740  [114300.02, 114300.03, 114300.04, 114300.5, 11...
# 9745  [114523.29, 114523.3, 114523.93, 114523.94, 11...
# 9750  [114428.0, 114428.01, 114428.02, 114429.15, 11...
# 9755  [114600.01, 114600.02, 114600.52, 114600.53, 1...
# 9760  [114512.9, 114512.91, 114513.3, 114513.85, 114...
#
#                                                 ask_qty       open       high  \
# 165   [0.37639, 0.0003, 0.0001, 0.00015, 0.0001, 0.0...  115000.00  115031.80
# 170   [1.39649, 0.00105, 0.0001, 0.0001, 0.0001, 0.0...  115133.26  115149.55
# 175   [3.8642, 0.015, 0.0001, 0.0001, 0.00015, 0.000...  115086.66  115086.66
# 180   [6.65878, 0.08571, 0.0001, 0.0001, 0.17453, 0....  115004.53  115004.53
# 185   [2.97392, 0.07097, 0.0001, 0.0001, 5e-05, 5e-0...  114940.03  114940.03
# ...                                                 ...        ...        ...
# 9740  [0.81305, 0.0007, 0.0001, 0.0001, 0.07212, 0.0...  114407.28  114407.28
# 9745  [0.50096, 0.00095, 5e-05, 5e-05, 0.0025, 0.000...  114488.80  114511.84
# 9750  [0.00587, 0.00095, 0.0001, 5e-05, 9e-05, 5e-05...  114410.99  114427.99
# 9755  [14.87457, 0.0001, 0.0001, 0.00015, 0.0001, 0....  114623.68  114623.69
# 9760  [12.54977, 0.0001, 5e-05, 0.0001, 0.04036, 0.0...  114495.31  114555.00
#
#             low      close    volume  ...  +change  -change     +DM     -DM  \
# 165   114999.99  115031.80   0.83129  ...   197.76  -179.93  197.76    0.00
# 170   115127.01  115149.55   2.11405  ...   117.75  -127.02  117.75    0.00
# 175   115086.65  115086.66   0.35388  ...   -62.89    40.36    0.00   40.36
# 180   114964.33  114964.33   6.88323  ...   -82.13   122.32    0.00  122.32
# 185   114940.02  114940.03   0.13348  ...   -64.50    24.31    0.00   24.31
# ...         ...        ...       ...  ...      ...      ...     ...     ...
# 9740  114288.69  114300.02  20.35663  ...  -148.38   209.56    0.00  209.56
# 9745  114446.09  114511.84   7.85143  ...   104.56  -157.40  104.56    0.00
# 9750  114358.67  114427.99   8.69192  ...   -83.85    87.42    0.00   87.42
# 9755  114590.76  114600.00  12.86815  ...   195.70  -232.09  195.70    0.00
# 9760  114495.31  114512.90   3.45791  ...   -68.69    95.45    0.00   95.45
#
#           +DI14      -DI14         DX        ADX  future 10t return   log ADX
# 165   31.729247  53.582703  25.615938  48.281185          -0.001712  3.877042
# 170   36.416724  50.044199  15.761427  44.918591          -0.002481  3.804852
# 175   35.474419  51.175762  18.120382  42.245800          -0.001413  3.743505
# 180   32.874833  54.727474  24.945280  40.575523          -0.001866  3.703165
# 185   33.025338  56.539984  26.254186  39.232984          -0.001079  3.669518
# ...         ...        ...        ...        ...                ...       ...
# 9740  15.306506  56.241520  57.213338  22.203717           0.002664  3.100260
# 9745  18.609981  49.297890  45.190505  23.736170          -0.001807  3.167000
# 9750  17.138944  49.685451  48.704530  25.400727           0.000116  3.234778
# 9755  24.561275  44.513481  28.884946  25.633008          -0.001466  3.243881
# 9760  23.508786  47.210878  33.515561  26.158512           0.000029  3.264175
#
# [1920 rows x 56 columns]

# %%
indicators = df[["delta price_t", "delta price_t-1", "delta price_t-2", "delta price_t-3", "delta price_t-4", "delta price_t-5", "delta price_t-6", "delta price_t-7", "order imbalance", "macd signal", "log spread", "mid price", "log ADX", "RSI", "open interest", "vol", "future 10t return", "ATR%"]]

# %%
indicators.to_csv("testing_indicators5_log.csv", index=False)

# %%
indicators
# Out:
#       delta price_t  delta price_t-1  delta price_t-2  delta price_t-3  \
# 165        0.001842         0.000289        -0.001624         0.001126
# 170        0.001023         0.001842         0.000289        -0.001624
# 175       -0.000546         0.001023         0.001842         0.000289
# 180       -0.001064        -0.000546         0.001023         0.001842
# 185       -0.000211        -0.001064        -0.000546         0.001023
# ...             ...              ...              ...              ...
# 9740      -0.001755        -0.000329        -0.002997         0.001367
# 9745       0.001851        -0.001755        -0.000329        -0.002997
# 9750      -0.000733         0.001851        -0.001755        -0.000329
# 9755       0.001502        -0.000733         0.001851        -0.001755
# 9760      -0.000760         0.001502        -0.000733         0.001851
#
#       delta price_t-4  delta price_t-5  delta price_t-6  delta price_t-7  \
# 165          0.000489        -0.001232        -0.002966        -0.000421
# 170          0.001126         0.000489        -0.001232        -0.002966
# 175         -0.001624         0.001126         0.000489        -0.001232
# 180          0.000289        -0.001624         0.001126         0.000489
# 185          0.001842         0.000289        -0.001624         0.001126
# ...               ...              ...              ...              ...
# 9740        -0.001599        -0.001997        -0.000943         0.000237
# 9745         0.001367        -0.001599        -0.001997        -0.000943
# 9750        -0.002997         0.001367        -0.001599        -0.001997
# 9755        -0.000329        -0.002997         0.001367        -0.001599
# 9760        -0.001755        -0.000329        -0.002997         0.001367
#
#       order imbalance  macd signal  log spread   mid price   log ADX  \
# 165          0.737349   -13.262129    -4.60517  115031.795  3.877042
# 170          0.812588     7.316102    -4.60517  115149.545  3.804852
# 175         -0.094832    17.843982    -4.60517  115086.655  3.743505
# 180         -0.804325    18.120021    -4.60517  114964.335  3.703165
# 185          0.188173    17.843683    -4.60517  114940.025  3.669518
# ...               ...          ...         ...         ...       ...
# 9740         0.714829   -90.963677    -4.60517  114300.015  3.100260
# 9745         0.888830   -80.565449    -4.60517  114523.285  3.167000
# 9750         0.998078   -73.913493    -4.60517  114427.995  3.234778
# 9755        -0.868227   -53.461483    -4.60517  114600.005  3.243881
# 9760        -0.935393   -41.845940    -4.60517  114512.895  3.264175
#
#             RSI  open interest       vol  future 10t return      ATR%
# 165   35.716472      88212.937  0.001199          -0.001712  0.001113
# 170   40.837265      88266.811  0.001436          -0.002481  0.001104
# 175   39.048538      88225.293  0.001483          -0.001413  0.001051
# 180   35.764382      88240.279  0.001454          -0.001866  0.001053
# 185   35.131889      88160.974  0.001479          -0.001079  0.000973
# ...         ...            ...       ...                ...       ...
# 9740  22.023216      89042.614  0.001236           0.002664  0.001103
# 9745  32.735034      89063.667  0.001263          -0.001807  0.001172
# 9750  30.925005      89138.097  0.001532           0.000116  0.001189
# 9755  38.441708      89107.365  0.001517          -0.001466  0.001237
# 9760  36.289073      89035.026  0.001650           0.000029  0.001207
#
# [1920 rows x 18 columns]
